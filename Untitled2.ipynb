# %%
from scholarly import scholarly, ProxyGenerator
from scholarly.publication_parser import PublicationParser
proxy="159.197.250.171:3128"
pg = ProxyGenerator()
success = pg.SingleProxy(http = proxy, https = proxy)
scholarly.use_proxy(pg)
# Out:
# Exception while testing proxy: HTTPConnectionPool(host='159.197.250.171', port=3128): Max retries exceeded with url: http://httpbin.org/ip (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000018E459FA100>, 'Connection to 159.197.250.171 timed out. (connect timeout=5)'))
# Unable to setup the proxy: http=159.197.250.171:3128 https=159.197.250.171:3128. Reason unknown.
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
# ...

# %%
publication_id = 2244396665447968936

pubs = [scholarly.fill(p) for p in scholarly.search_citedby(publication_id)]
# Out:
# ---------------------------------------------------------------------------
# MaxTriesExceededException                 Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 publication_id = 2244396665447968936
# ----> 3 pubs = [scholarly.fill(p) for p in scholarly.search_citedby(publication_id)]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\scholarly\_scholarly.py:167, in _Scholarly.search_citedby(self, publication_id, **kwargs)
#     159 """Searches by Google Scholar publication id and returns a generator of Publication objects.
#     160
#     161 :param publication_id: Google Scholar publication id
#    (...)
#     164 For the remaining parameters, see documentation of `search_pubs`.
#     165 """
#     166 url = self._construct_url(_CITEDBYSEARCH.format(str(publication_id)), **kwargs)
# --> 167 return self.__nav.search_publications(url)
#
# ...

# %%
publication_idd = 13068108630464812856

pubs2 = [scholarly.fill(p) for p in scholarly.search_citedby(publication_idd)]
# Out:
# ---------------------------------------------------------------------------
# MaxTriesExceededException                 Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 publication_idd = 13068108630464812856
# ----> 3 pubs2 = [p for p in scholarly.search_citedby(publication_idd)]
#
# Input In [3], in <listcomp>(.0)
#       1 publication_idd = 13068108630464812856
# ----> 3 pubs2 = [p for p in scholarly.search_citedby(publication_idd)]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\scholarly\publication_parser.py:90, in _SearchScholarIterator.__next__(self)
#      87     url = self._soup.find(
#      88         class_='gs_ico gs_ico_nav_next').parent['href']
#      89     self._url = url
# ---> 90     self._load_url(url)
#      91     return self.__next__()
#      92 else:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\scholarly\publication_parser.py:59, in _SearchScholarIterator._load_url(self, url)
# ...

# %%
pubs
# Out:
# [{'container_type': 'Publication',
#   'source': <PublicationSource.PUBLICATION_SEARCH_SNIPPET: 'PUBLICATION_SEARCH_SNIPPET'>,
#   'bib': {'title': 'The impacts of ocean acidification on marine ecosystems and reliant human communities',
#    'author': ['SC Doney', 'DS Busch', 'SR Cooley'],
#    'pub_year': '2020',
#    'venue': 'Annual Review of …',
#    'abstract': 'Rising atmospheric carbon dioxide (CO 2) levels, from fossil fuel combustion and deforestation, along with agriculture and land-use practices are causing wholesale'},
#   'filled': False,
#   'gsrank': 1,
#   'pub_url': 'https://par.nsf.gov/biblio/10164807',
#   'author_id': ['PZq3DmAAAAAJ', 'FN5x2UEAAAAJ', 'jQT5KrsAAAAJ'],
#   'url_scholarbib': '/scholar?hl=en&q=info:AwMojq99LJgJ:scholar.google.com/&output=cite&scirp=0&hl=en',
# ...

# %%
for pub in pubs:
    scholarly.fill(pub)

# %%
uni=scholarly.search_org('gazi üniversitesi')
uni
# Out:
# [{'Organization': 'Gazi University', 'id': '16466720366002481050'}]

# %%
name=scholarly.search_author_by_organization(uni[0]['id'])
name
# Out:
# <generator object Navigator.search_authors at 0x0000018E48131200>

# %%
author=next(name)

# %%
author
# Out:
# {'container_type': 'Author',
#  'filled': [],
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#  'scholar_id': 'D-hHCE8AAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=D-hHCE8AAAAJ',
#  'name': 'Ebru Kılıç Çakmak',
#  'affiliation': 'Bilgisayar ve Öğretim Teknolojileri Eğitimi, Gazi Üniversitesi',
#  'email_domain': '@gazi.edu.tr',
#  'interests': ['Uzaktan eğitim',
#   'e-öğrenme',
#   'teknoloji entegrasyonu',
#   'insan bilgisayar etkileşimi'],
#  'citedby': 22467}

# %%
type(uni)
# Out:
# list

# %%
uni[0]['id']
# Out:
# '16466720366002481050'

# %%
author2=next(next(name))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 author2=next(next(name))
#
# TypeError: 'dict' object is not an iterator

# %%
unii=scholarly.search_org('Ankara ')
unii
# Out:
# [{'Organization': 'Ankara Üniversitesi', 'id': '10637576479501333415'},
#  {'Organization': 'Hacettepe University', 'id': '2182971719771222960'},
#  {'Organization': 'Middle East Technical University',
#   'id': '9340431717369407499'}]
