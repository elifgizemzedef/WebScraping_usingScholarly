# %%
from scholarly import scholarly, ProxyGenerator
from scholarly.publication_parser import PublicationParser
#proxy="164.100.130.128:8080"
#pg = ProxyGenerator()
#success = pg.SingleProxy(http = proxy, https = proxy)
#scholarly.use_proxy(pg)

# %%
deneme = scholarly.search_single_pub("Partial transmit sequences for PAPR reduction using parallel tabu search algorithm in OFDM systems", filled=True)

# %%
deneme
# Out:
# {'container_type': 'Publication',
#  'source': <PublicationSource.PUBLICATION_SEARCH_SNIPPET: 'PUBLICATION_SEARCH_SNIPPET'>,
#  'bib': {'title': 'Partial transmit sequences for PAPR reduction using parallel tabu search algorithm in OFDM systems',
#   'author': 'Taspinar, Necmi and Kalinli, Adem and Yildirim, Mahmut',
#   'pub_year': '2011',
#   'venue': 'IEEE Communications Letters',
#   'abstract': 'In this letter, partial transmit sequences (PTS) based on parallel tabu search (Parallel TS-PTS) scheme is proposed to reduce the peak-to-average power ratio (PAPR) of orthogonal frequency division multiplexing (OFDM) signals. PTS is a distortionless PAPR reduction technique, but its high search complexity for finding optimal phase factors must be reduced for usable applications. Parallel TS-PTS is compared to different PTS schemes for PAPR reduction and search complexity performances. The simulation results show that the',
#   'publisher': 'IEEE',
#   'pages': '974--976',
# ...

# %%
result = scholarly.bibtex(deneme)

# %%
result
# Out:
# '@article{taspinar2011partial,\n abstract = {In this letter, partial transmit sequences (PTS) based on parallel tabu search (Parallel TS-PTS) scheme is proposed to reduce the peak-to-average power ratio (PAPR) of orthogonal frequency division multiplexing (OFDM) signals. PTS is a distortionless PAPR reduction technique, but its high search complexity for finding optimal phase factors must be reduced for usable applications. Parallel TS-PTS is compared to different PTS schemes for PAPR reduction and search complexity performances. The simulation results show that the},\n author = {Taspinar, Necmi and Kalinli, Adem and Yildirim, Mahmut},\n journal = {IEEE Communications Letters},\n number = {9},\n pages = {974--976},\n pub_year = {2011},\n publisher = {IEEE},\n title = {Partial transmit sequences for PAPR reduction using parallel tabu search algorithm in OFDM systems},\n venue = {IEEE Communications Letters},\n volume = {15}\n}\n'

# %%
search_query = scholarly.search_pubs('Perception of physical stability and center of mass of 3D objects')

# %%
filledd= scholarly.fill(next(search_query))

# %%
filledd
# Out:
# {'container_type': 'Publication',
#  'source': <PublicationSource.PUBLICATION_SEARCH_SNIPPET: 'PUBLICATION_SEARCH_SNIPPET'>,
#  'bib': {'title': 'Perception of physical stability and center of mass of 3-D objects',
#   'author': 'Cholewiak, Steven A and Fleming, Roland W and Singh, Manish',
#   'pub_year': '2015',
#   'venue': 'Journal of vision',
#   'abstract': 'Humans can judge from vision alone whether an object is physically stable or not. Such judgments allow observers to predict the physical behavior of objects, and hence to guide their motor actions. We investigated the visual estimation of physical stability of 3-D objects (shown in stereoscopically viewed rendered scenes) and how it relates to visual estimates of their center of mass (COM). In Experiment 1, observers viewed an object near the edge of a table and adjusted its tilt to the perceived critical angle, ie, the tilt angle at which the object',
# ...

# %%
deneme2=scholarly.citedby(filledd)

# %%
deneme2

# %%
publication_id = 2244396665447968936

pubs = [p for p in scholarly.search_citedby(publication_id)]

# %%
pubs
# Out:
# [{'container_type': 'Publication',
#   'source': <PublicationSource.PUBLICATION_SEARCH_SNIPPET: 'PUBLICATION_SEARCH_SNIPPET'>,
#   'bib': {'title': 'The impacts of ocean acidification on marine ecosystems and reliant human communities',
#    'author': ['SC Doney', 'DS Busch', 'SR Cooley'],
#    'pub_year': '2020',
#    'venue': 'Annual Review of …',
#    'abstract': 'Rising atmospheric carbon dioxide (CO 2) levels, from fossil fuel combustion and deforestation, along with agriculture and land-use practices are causing wholesale'},
#   'filled': False,
#   'gsrank': 1,
#   'pub_url': 'https://par.nsf.gov/biblio/10164807',
#   'author_id': ['PZq3DmAAAAAJ', 'FN5x2UEAAAAJ', 'jQT5KrsAAAAJ'],
#   'url_scholarbib': '/scholar?hl=en&q=info:AwMojq99LJgJ:scholar.google.com/&output=cite&scirp=0&hl=en',
# ...
