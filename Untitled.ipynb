# %%
from scholarly import scholarly
from scholarly import ProxyGenerator
pg = ProxyGenerator()
scholarly.use_proxy(pg, pg)

# %%
# Retrieve the author's data, fill-in, and print
# Get an iterator for the author results
search_query = scholarly.search_author('Adem Kalınlı')
# Retrieve the first result from the iterator
first_author_result = next(search_query)
scholarly.pprint(first_author_result)

# Retrieve all the details for the author
author = scholarly.fill(first_author_result )
scholarly.pprint(author)

# Take a closer look at the first publication
first_publication = author['publications'][0]
first_publication_filled = scholarly.fill(first_publication)
scholarly.pprint(first_publication_filled)

# Print the titles of the author's publications
publication_titles = [pub['bib']['title'] for pub in author['publications']]
print(publication_titles)

# Which papers cited that publication?
citations = [citation['bib']['title'] for citation in scholarly.citedby(first_publication_filled)]
print(citations)
# Out:
# b"{'affiliation': 'Middle East Technical University',\n 'citedby': 1202,\n 'email_domain': '@metu.edu.tr',\n 'filled': False,\n 'interests': ['Yapay Zeka',\n               'Zeki Optimizasyon Algoritmalar\xc4\xb1',\n               'Yapay Sinir A\xc4\x9flar\xc4\xb1',\n               'T\xc4\xb1p Bili\xc5\x9fimi'],\n 'name': 'Adem KALINLI',\n 'scholar_id': 'nwDz-xVu1FcC',\n 'source': 'SEARCH_AUTHOR_SNIPPETS',\n 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=nwDz-xVu1FcC'}"
# b"{'affiliation': 'Middle East Technical University',\n 'citedby': 1202,\n 'citedby5y': 475,\n 'cites_per_year': {1999: 4,\n                    2000: 7,\n                    2001: 5,\n                    2002: 13,\n                    2003: 10,\n                    2004: 12,\n                    2005: 30,\n                    2006: 20,\n                    2007: 37,\n                    2008: 33,\n                    2009: 49,\n                    2010: 31,\n                    2011: 55,\n                    2012: 73,\n                    2013: 90,\n                    2014: 60,\n                    2015: 97,\n                    2016: 84,\n                    2017: 68,\n                    2018: 80,\n                    2019: 89,\n                    2020: 68,\n                    2021: 94,\n                    2022: 75},\n 'coauthors': [{'affiliation': 'Computer Engineering, Erciyes University',\n                'filled': False,\n                'name': 'Dervis Karaboga',\n                'scholar_id': 'aC77_cUAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Elektrik Elektronik Profes\xc3\xb6r\xc3\xbc, Erciyes '\n                               '\xc3\x9cniversitesi',\n                'filled': False,\n                'name': 'Karaboga Nurhan',\n                'scholar_id': 'Ot3jrBwAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Computer Engineering, Gaziantep University',\n                'filled': False,\n                'name': 'Bulent Haznedar',\n                'scholar_id': '0viljZ4AAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Erciyes \xc3\x9cniversitesi',\n                'filled': False,\n                'name': 'Necmi TA\xc5\x9ePINAR',\n                'scholar_id': 'm0fEV5IAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Professor of Software Engineering at Gazi '\n                               'University Computer Engineering Department, '\n                               'Ankara, Turkey',\n                'filled': False,\n                'name': 'Seref Sagiroglu',\n                'scholar_id': 'aQWCNn4AAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Instructor,Mustafa Kemal University',\n                'filled': False,\n                'name': 'Mustafa Turan Arslan',\n                'scholar_id': 'cNA_7l0AAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Erciyes \xc3\x9cniversitesi',\n                'filled': False,\n                'name': 'Rustu Akay',\n                'scholar_id': 'KC_QwREAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Dept. of Computer Engineering, Erciyes '\n                               'University, Melikgazi, 38039, Kayseri, '\n                               'Turkiye.',\n                'filled': False,\n                'name': 'Alper Basturk',\n                'scholar_id': '_Hw1ZXoAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Kayseri University',\n                'filled': False,\n                'name': 'Mehmet Cemal Acar',\n                'scholar_id': 'lOyJsiUAAAAJ',\n                'source': 'CO_AUTHORS_LIST'}],\n 'email_domain': '@metu.edu.tr',\n 'filled': True,\n 'hindex': 17,\n 'hindex5y': 11,\n 'homepage': 'https://avesis.metu.edu.tr/kalinlia',\n 'i10index': 23,\n 'i10index5y': 14,\n 'interests': ['Yapay Zeka',\n               'Zeki Optimizasyon Algoritmalar\xc4\xb1',\n               'Yapay Sinir A\xc4\x9flar\xc4\xb1',\n               'T\xc4\xb1p Bili\xc5\x9fimi'],\n 'name': 'Adem KALINLI',\n 'organization': 9340431717369407499,\n 'public_access': {'available': 0, 'not_available': 0},\n 'publications': [{'author_pub_id': 'nwDz-xVu1FcC:u5HHmVD_uO8C',\n                   'bib': {'citation': 'Engineering Applications of Artificial '\n                              ...
# b"{'author_pub_id': 'nwDz-xVu1FcC:u5HHmVD_uO8C',\n 'bib': {'abstract': 'In order to transform and analyse signals that have been '\n                     'sampled from analogue sources, digital signal processing '\n                     '(DSP) algorithms are employed. The advantages of DSP are '\n                     'based on the fact that the performance of the applied '\n                     'algorithm is always predictable. There is no dependence '\n                     'on the tolerances of electrical components as in '\n                     'analogue systems. DSP algorithms can be reasonably '\n                     'described as a digital filter. Digital filters can be '\n                     'broadly divided into two-sub classes: finite '\n                     'impulse-response filters and infinite impulse-response '\n                     '(IIR) filters. Because the error surface of IIR filters '\n                     'is generally multi-modal, global optimisation techniques '\n                     'are required in order to avoid local minima and design '\n                     'efficient digital IIR filters. In this work, a new '\n                     'method based on the ant colony optimisation algorithm '\n                     'with global optimisation ability is proposed for digital '\n                     'IIR filter design. Simulation results show that the '\n                     'proposed approach is \xe2\x80\xa6',\n         'author': 'Nurhan Karaboga and Adem Kalinli and Dervis Karaboga',\n         'citation': 'Engineering Applications of Artificial Intelligence 17 '\n                     '(3), 301-309, 2004',\n         'journal': 'Engineering Applications of Artificial Intelligence',\n         'number': '3',\n         'pages': '301-309',\n         'pub_year': 2004,\n         'publisher': 'Pergamon',\n         'title': 'Designing digital IIR filters using ant colony optimisation '\n                  'algorithm',\n         'volume': '17'},\n 'citedby_url': '/scholar?hl=en&cites=15415586336572811440',\n 'cites_id': ['15415586336572811440'],\n 'cites_per_year': {2004: 3,\n                    2005: 6,\n                    2006: 2,\n                    2007: 8,\n                    2008: 8,\n                    2009: 15,\n                    2010: 7,\n                    2011: 14,\n                    2012: 14,\n                    2013: 15,\n                    2014: 10,\n                    2015: 21,\n                    2016: 15,\n                    2017: 14,\n                    2018: 7,\n                    2019: 5,\n                    2020: 7,\n                    2021: 5,\n                    2022: 3},\n 'filled': True,\n 'num_citations': 181,\n 'pub_url': 'https://www.sciencedirect.com/science/article/pii/S0952197604000181',\n 'source': 'AUTHOR_PUBLICATION_ENTRY',\n 'url_related_articles': '/scholar?oi=bibs&hl=en&q=related:sKjJCxkq79UJ:scholar.google.com/'}"
# ['Designing digital IIR filters using ant colony optimisation algorithm', 'Artificial immune algorithm for IIR filter design', 'New approaches to determine the ultimate bearing capacity of shallow foundations based on artificial neural networks and ant colony optimization', 'Partial transmit sequences for PAPR reduction using parallel tabu search algorithm in OFDM systems', 'A new method for adaptive IIR filter design based on tabu search algorithm', 'Training ANFIS structure using simulated annealing algorithm for dynamic systems identification', 'Designing digital FIR filters using Tabu search algorithm', 'Training recurrent neural networks by using parallel tabu search algorithm based on crossover operation', 'Elman network with embedded memory for system identification', 'Component value selection for active filters using parallel tabu search algorithm', 'Training ANFIS using genetic algorithm for dynamic systems identification', 'Tuning PID controller parameters using Tabu search algorithm', 'Optimal circuit design using immune algorithm', 'Determining resonant frequencies of various microstrip antennas within a single neural model trained using parallel tabu search algorithm', 'Performance comparison of machine learning methods for prognosis of hormone receptor status in breast cancer tissue samples', 'Training recurrent neural networks for dynamic system identification using parallel tabu search algorithm', 'Parallel population-based algorithm portfolios: An empirical study', 'A fractional-order model of COVID-19 considering the fear effect of the media and social networks on the community', 'A modified touring ant colony optimisation algorithm for continuous functions', 'Artificial neural network for the prediction of chromosomal abnormalities in azoospermic males', 'Parallel ant colony optimization algorithm based neural method for determining resonant frequencies of various microstrip antennas', 'Optimizing ANFIS using simulated annealing algorithm for classification of microarray gene expression cancer data', 'A parallel tabu search algorithm for digital filter design', 'A parallel ant colony optimization algorithm based on crossover operation', 'Elman Ağının Sımulated Annealıng Algoritması Kullanarak Sistem Kimliklendirme İçin Eğitilmesi', 'Simulated annealing algorithm-based Elman network for dynamic system identification', 'Comparison of fine-grained and coarse-grained parallel models in particle swarm optimization algorithm', 'A comparative study of statistical and artificial intelligence based classification algorithms on central nervous system cancer microarray gene expression data', 'Training recurrent neural networks using tabu search algorithm', 'Geribeslemeli yapay sinir ağlarının genetik operatörlere dayalı tabu araştırma algoritması kullanarak eğitilmesi', 'Mathematical modeling of breast cancer in a mixed immune-chemotherapy treatment considering the effect of ketogenic diet', 'A comparative study on determining nonlinear function parameters of the Izhikevich neuron model', 'Training ANFIS structure using genetic algorithm for liver cancer classification based on microarray gene expression data', 'Karaciğer mikrodizi kanser verisinin sınıflandırılması için genetik algoritma kullanarak ANFIS’in eğitilmesi', 'An automated prognosis system for estrogen hormone status assessment in breast cancer tissue samples', 'Genetic algorithm model based on dominant gene selection operator', 'Elman Ağının Benzetilmiş Tavlama Algoritması Kullanarak Eğitilmesi', 'AKTİF FİLTRELER İÇİN DEVRE ELEMANI DEĞERLERİNİN KARINCA KOLONİ ALGORİTMASI KULLANARAK SEÇİMİ', 'An immune algorithm for numeric function optimisation', 'Tabu Search Algorithm for Combinatorial Optimisation Problems', 'Trombofili hastalığı ile genetik bozukluklar arasındaki ilişkinin adaptif ağ tabanlı bulanık mantık çıkarım sistemi (ANFIS) ile tespit edilmesi', 'Detection of the relationship between thrombophilia disease with genetic disorders by adaptive neuro- ...
# ['Computational intelligence: an introduction', 'Filter modeling using gravitational search algorithm', 'Fruit classification using computer vision and feedforward neural network', 'Electric load forecasting by seasonal recurrent SVR (support vector regression) with chaotic artificial bee colony algorithm', 'Optimal multi-level thresholding based on maximum Tsallis entropy via an artificial bee colony approach', 'An advanced ACO algorithm for feature subset selection', 'Digital IIR filter design using differential evolution algorithm', 'Seeker optimization algorithm for digital IIR filter design', 'Magnetic resonance brain image classification by an improved artificial bee colony algorithm', 'PID controller design of nonlinear systems using an improved particle swarm optimization approach', 'Particle swarm optimisation: classical and quantum perspectives', 'Artificial immune algorithm for IIR filter design', 'Particle swarm optimization with quantum infusion for system identification', 'Modeling NOx emissions from coal-fired utility boilers using support vector regression with ant colony optimization', 'Optimal design of FIR fractional order differentiator using cuckoo search algorithm', 'Optimal fractional delay-IIR filter design using cuckoo search algorithm', 'A new mutated quantum-behaved particle swarm optimizer for digital IIR filter design', 'Swarm and evolutionary computing algorithms for system identification and filter design: A comprehensive review', 'An adaptive inertia weight particle swarm optimization algorithm for IIR digital filter', 'Computational intelligence: an introduction', 'Investigation of ant system parameter interactions by using design of experiments for job-shop scheduling problems', 'Membrane computing model for IIR filter design', 'Gravitation search algorithm: application to the optimal IIR filter design', 'Artificial bee colony for two dimensional protein folding', 'A soft computing-based approach for integrated training and rule extraction from artificial neural networks: DIFACONN-miner', 'Nature–inspired intelligence: a review of selected methods and applications', 'The design of IIR digital filter based on chaos particle swarm optimization algorithm', 'Optimal IIR filter design using gravitational search algorithm with wavelet mutation', 'Parameter identification using particle swarm optimization', 'Component value selection for active filters using parallel tabu search algorithm', 'TACO-miner: An ant colony based algorithm for rule extraction from trained neural networks', 'The residue logarithmic number system: theory and implementation', 'Chaotic artificial bee colony used for cluster analysis', 'A new design method for adaptive IIR system identification using hybrid particle swarm optimization and gravitational search algorithm', 'Face pose estimation by chaotic artificial bee colony', 'UCAV path planning based on FSCABC', 'Adaptive infinite impulse response system identification using modified-interior search algorithm with Lèvy flight', 'Swarm intelligence and signal processing [DSP Exploratory]', 'Two-stage ensemble memetic algorithm: Function optimization and digital IIR filter design', 'Bat algorithm: application to adaptive infinite impulse response system identification', 'Optimal design of fractional delay FIR filter using cuckoo search algorithm', 'Digital IIR filters design using differential evolution algorithm with a controllable probabilistic population size', 'A novel design and implementation technique for low complexity variable digital filters using multi-objective artificial bee colony optimization and a minimal …', 'Optimal circuit design using immune algorithm', 'Ant colony system for segmentation and classification of microcalcification in mammograms', 'IIR model identification using a modified inclined planes system optimization algorithm', 'A new design method for adaptive IIR system identification using hybrid CPSO and DE', 'Predator prey optimization method for t ...

# %%
search_query = scholarly.search_author('Steven A Cholewiak')
search_query
# Out:
# <generator object Navigator.search_authors at 0x000002CFAA103970>

# %%
first_author_result = next(search_query)

# %%
author = scholarly.fill(first_author_result )
author
# Out:
# {'container_type': 'Author',
#  'filled': ['basics',
#   'indices',
#   'counts',
#   'coauthors',
#   'publications',
#   'public_access'],
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#  'scholar_id': '4bahYMkAAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=4bahYMkAAAAJ',
#  'name': 'Steven A. Cholewiak, PhD',
#  'affiliation': 'Vision Scientist at Google LLC',
#  'email_domain': '@google.com',
#  'interests': ['Depth Cues',
#   '3D Shape',
#   'Shape from Texture & Shading',
#   'Naive Physics',
#   'Haptics'],
#  'citedby': 444,
#  'organization': 6518679690484165796,
#  'homepage': 'http://steven.cholewiak.com/',
#  'citedby5y': 308,
#  'hindex': 10,
#  'hindex5y': 10,
#  'i10index': 11,
#  'i10index5y': 10,
#  'cites_per_year': {2008: 3,
#   2009: 5,
#   2010: 7,
#   2011: 9,
#   2012: 22,
#   2013: 17,
#   2014: 16,
#   2015: 17,
#   2016: 36,
#   2017: 32,
#   2018: 30,
#   2019: 57,
#   2020: 66,
#   2021: 78,
#   2022: 44},
#  'coauthors': [{'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'Smr99uEAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Martin Banks',
#    'affiliation': 'Professor of Vision Science, UC Berkeley'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'ruUKktgAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Roland Fleming',
#    'affiliation': 'Kurt Koffka Professor of Experimental Psychology, University of Giessen'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': '3xJXtlwAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Gordon D. Love',
#    'affiliation': 'Durham University, Computer Science & Physics'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'OiVOAHMAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Hong Z Tan',
#    'affiliation': 'Professor of ECE, Purdue University'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'MnUboHYAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Ari Weinstein',
#    'affiliation': 'Deepmind'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'dqokykoAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Chia-Chien Wu',
#    'affiliation': "Brigham and Women's Hospital/Harvard Medical School"},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'KoJrMIAAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Jacob Feldman',
#    'affiliation': 'Professor of Psychology and Cognitive Science, Rutgers University'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'aYyDsZ0AAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Pratul Srinivasan',
#    'affiliation': 'Research Scientist at Google Research'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': '9XRvM88AAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Manish Singh',
#    'affiliation': 'Rutgers University, New Brunswick, NJ'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'tD7OGTQAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Vivek Labhishetty',
#    'affiliation': 'Senior Director - Clinical Affairs, Neurolens Inc.,'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': '6H0mhLUAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Ren Ng',
#    'affiliation': 'Professor in Computer Science, University of California, Berkeley'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'FoVvIK0AAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Peter C. Pantelis',
#    'affiliation': 'Formerly: Indiana University, Rutgers University, University of Pennsylvania'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'rNTIQXYAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Steven W Zucker',
#    'affiliation': 'Yale University'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'JPZWLKQAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Ben Kunsberg',
#    'affiliation': 'Brown University'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'LB2Ji0sAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'David S Ebert',
#    'affiliation': 'Gallogly Professor of ECE, Assoc. VPRP, University of Oklahoma'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'rRJ9wTJMUB8C',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Joshua B. Tenenbaum',
#    'affiliation': 'MIT'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'bTdT7hAAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Chris Baker',
#    'affiliation': 'Chief Scientist, ISEE AI'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'nHx9IgYAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Peter Shirley',
#    'affiliation': 'Nvidia Corporation'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': '9xN3AFkAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Emma Alexander',
#    'affiliation': 'Northwestern University'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': '7QU97-8AAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Daniel Holtmann-Rice',
#    'affiliation': 'Graduate Student in Computer Science, Yale University'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'KXQb7CAAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Sung-Ho Kim',
#    'affiliation': 'Professor of Psychology, Ewha Womans University'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'xZLjeAMAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Ozan Cakmakci',
#    'affiliation': 'Staff Optical Designer, Project Glass, Google'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'Ky6YeHQAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Zeynep Başgöze',
#    'affiliation': 'Postdoctoral Associate, University of Minnesota, Psychiatry and Behavioral Sciences'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': '6Wo3XX4AAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Emily Averill Cooper',
#    'affiliation': 'University of California, Berkeley'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'AE7Xvl0AAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'David Luebke',
#    'affiliation': 'Vice President of Research, NVIDIA Corporation'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'FhyBsnQAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Kaan Akşit',
#    'affiliation': 'Associate Professor of Computational Light, University College London'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'RbUgwbwAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Anjul Patney',
#    'affiliation': 'NVIDIA Research'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'WzhSQzkAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Josef Spjut',
#    'affiliation': 'Research Scientist, NVIDIA'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'HcMv-28AAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Ward Lopes',
#    'affiliation': 'Senior Research Scientist, NVIDIA'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'OTLc4PIAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Austin ROORDA',
#    'affiliation': 'UC Berkeley'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'NN4GKo8AAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Melissa M. Kibbe',
#    'affiliation': 'Associate Professor, Boston University'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'b9u-pTsAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Flip Phillips',
#    'affiliation': 'Professor of Motion Picture Science, Rochester Institute of Technology'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'LgU3FXIAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Roger W. Cholewiak',
#    'affiliation': 'Senior Research Psychologist, Emeritus, Princeton University'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': '1M3nfPAAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Agostino Gibaldi',
#    'affiliation': 'University of California at Berkeley'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'I23YUh8AAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Morgan McGuire',
#    'affiliation': 'Roblox, University of Waterloo, and McGill University'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': '23w3sSMAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Timothy Gerstner',
#    'affiliation': 'Rutgers University'}],
#  'publications': [{'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A frequency-domain analysis of haptic gratings',
#     'pub_year': '2009',
#     'citation': 'IEEE Transactions on Haptics 3 (1), 3-14, 2009'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:u5HHmVD_uO8C',
#    'num_citations': 63,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=18104797610932568627',
#    'cites_id': ['18104797610932568627']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Haptic identification of stiffness and force magnitude',
#     'pub_year': '2008',
#     'citation': '2008 Symposium on Haptic Interfaces for Virtual Environment and Teleoperator …, 2008'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:u-x6o8ySG0sC',
#    'num_citations': 55,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9361504114905053519',
#    'cites_id': ['9361504114905053519']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Chromablur: Rendering chromatic eye aberration improves accommodation and realism',
#     'pub_year': '2017',
#     'citation': 'ACM Transactions on Graphics (TOG) 36 (6), 1-12, 2017'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:LI9QrySNdTsC',
#    'num_citations': 51,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5738786554683183717',
#    'cites_id': ['5738786554683183717'],
#    'public_access': True},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Creating correct blur and its effect on accommodation',
#     'pub_year': '2018',
#     'citation': 'Journal of Vision 18 (9), 1-1, 2018'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:kz9GbA2Ns4gC',
#    'num_citations': 41,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8341328198898590153',
#    'cites_id': ['8341328198898590153'],
#    'public_access': True},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Inferring the intentional states of autonomous virtual agents',
#     'pub_year': '2014',
#     'citation': 'Cognition 130 (3), 360-379, 2014'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:roLk4NBRz8UC',
#    'num_citations': 37,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13500426973403217301',
#    'cites_id': ['13500426973403217301']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Visual perception of the physical stability of asymmetric three-dimensional objects',
#     'pub_year': '2013',
#     'citation': 'Journal of vision 13 (4), 12-12, 2013'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:ufrVoPGSRksC',
#    'num_citations': 30,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13400046667572762242',
#    'cites_id': ['13400046667572762242'],
#    'public_access': True},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Perception of physical stability and center of mass of 3-D objects',
#     'pub_year': '2015',
#     'citation': 'Journal of vision 15 (2), 13-13, 2015'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:hMsQuOkrut0C',
#    'num_citations': 24,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15736880631888070187',
#    'cites_id': ['15736880631888070187'],
#    'public_access': True},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Colour, contours, shading and shape: flow interactions reveal anchor neighbourhoods',
#     'pub_year': '2018',
#     'citation': 'Interface focus 8 (4), 20180019, 2018'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:k8Z6L05lTy4C',
#    'num_citations': 18,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3525044598165528785',
#    'cites_id': ['3525044598165528785'],
#    'public_access': True},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': "Contributions of foveal and non-foveal retina to the human eye's focusing response",
#     'pub_year': '2019',
#     'citation': 'Journal of Vision 19 (12), 18-18, 2019'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:i2xiXl-TujoC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1348845672647133078',
#    'cites_id': ['1348845672647133078'],
#    'public_access': True},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Discrimination of real and virtual surfaces with sinusoidal and triangular gratings using the fingertip and stylus',
#     'pub_year': '2012',
#     'citation': 'IEEE transactions on haptics 6 (2), 181-192, 2012'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:eQOLeE2rZwMC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16686586457504436047',
#    'cites_id': ['16686586457504436047']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A perceptual eyebox for near-eye displays',
#     'pub_year': '2020',
#     'citation': 'Optics Express 28 (25), 38008-38028, 2020'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:HbR8gkJAVGIC',
#    'num_citations': 10,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1578220240044944327',
#    'cites_id': ['1578220240044944327']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Varifocal virtuality: a novel optical layout for near-eye display',
#     'pub_year': '2017',
#     'citation': 'ACM SIGGRAPH 2017 Emerging Technologies, 1-2, 2017'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:MLfJN-KU85MC',
#    'num_citations': 9,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=18130195908171454472',
#    'cites_id': ['18130195908171454472']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Agency and rationality: Adopting the intentional stance toward evolved virtual agents.',
#     'pub_year': '2016',
#     'citation': 'Decision 3 (1), 40, 2016'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:TIZ-Mc8IlK0C',
#    'num_citations': 9,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6290421033584304174',
#    'cites_id': ['6290421033584304174'],
#    'public_access': True},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Lags and leads of accommodation in humans: Fact or fiction?',
#     'pub_year': '2021',
#     'citation': 'Journal of vision 21 (3), 21-21, 2021'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:foquWX3nUaYC',
#    'num_citations': 8,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8977577668804567954',
#    'cites_id': ['8977577668804567954'],
#    'public_access': True},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Intra-and intermanual curvature aftereffect can be obtained via tool-touch',
#     'pub_year': '2013',
#     'citation': 'IEEE Transactions on Haptics, 1, 2013'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:LkGwnXOMwfcC',
#    'num_citations': 7,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3148891647529568450',
#    'cites_id': ['3148891647529568450']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Perception of intentions and mental states in autonomous virtual agents',
#     'pub_year': '2011',
#     'citation': 'Journal of Vision 11 (11), 1990-1995, 2011'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:9yKSN-GCB0IC',
#    'num_citations': 7,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11164555767023932779',
#    'cites_id': ['11164555767023932779']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Frequency analysis of the detectability of virtual haptic gratings',
#     'pub_year': '2007',
#     'citation': 'Second Joint EuroHaptics Conference and Symposium on Haptic Interfaces for …, 2007'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:d1gkVwhDpl0C',
#    'num_citations': 6,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10022477494945159835',
#    'cites_id': ['10022477494945159835']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Distinguishing between texture and shading flows for 3D shape estimation',
#     'pub_year': '2015',
#     'citation': 'Journal of vision 15 (12), 965-965, 2015'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:KUbvn5osdkgC',
#    'num_citations': 5,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16174097279596467563',
#    'cites_id': ['16174097279596467563']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Predicting 3D shape perception from shading and texture flows',
#     'pub_year': '2014',
#     'citation': 'Journal of Vision 14 (10), 1113-1113, 2014'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:EYYDruWGBe4C',
#    'num_citations': 5,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15050053021465917913',
#    'cites_id': ['15050053021465917913']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'The perception of physical stability of 3d objects: The role of parts',
#     'pub_year': '2010',
#     'citation': 'Journal of Vision 10 (7), 77-77, 2010'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:zYLM7Y9cAGgC',
#    'num_citations': 5,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8373403526432059892',
#    'cites_id': ['8373403526432059892']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Optimal allocation of quantized human eye depth perception for multi-focal 3D display design',
#     'pub_year': '2021',
#     'citation': 'Optics Express 29 (7), 9878-9896, 2021'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:Dip1O2bNi0gC',
#    'num_citations': 4,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6905186602124309655',
#    'cites_id': ['6905186602124309655']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Towards a unified explanation of shape from shading and texture',
#     'pub_year': '2013',
#     'citation': 'Journal of Vision 13 (9), 258-258, 2013'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:_FxGoFyzp5QC',
#    'num_citations': 4,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2012897025252602369',
#    'cites_id': ['2012897025252602369']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Lags and leads of accommodation are smaller than previously thought',
#     'pub_year': '2020',
#     'citation': 'Investigative Ophthalmology & Visual Science 61 (7), 1717-1717, 2020'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:PoWvk5oyLR8C',
#    'num_citations': 3,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4678869152067448389',
#    'cites_id': ['4678869152067448389']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Pseudo light-field display apparatus',
#     'pub_year': '2019',
#     'citation': 'US Patent App. 16/179,356, 2019'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:-FonjvnnhkoC',
#    'num_citations': 2,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15019383484890135219',
#    'cites_id': ['15019383484890135219']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'ChromaBlur: Rendering Chromatic Eye Aberration Improves Accommodation and Realism in HMDs',
#     'pub_year': '2017',
#     'citation': '3D Image Acquisition and Display: Technology, Perception and Applications …, 2017'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:tuHXwOkdijsC',
#    'num_citations': 2,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13315911430222136838',
#    'cites_id': ['13315911430222136838']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Lags and leads of accommodation: Fact or fiction?',
#     'pub_year': '2020',
#     'citation': 'Journal of Vision 20 (11), 1650-1650, 2020'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:xtoqd-5pKcoC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8235579066685371625',
#    'cites_id': ['8235579066685371625']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Rendering correct blur',
#     'pub_year': '2017',
#     'citation': 'Journal of Vision 17 (10), 403-403, 2017'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:lmc2jWPfTJgC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6006228010533872315',
#    'cites_id': ['6006228010533872315']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Appearance controls interpretation of orientation flows for 3D shape estimation',
#     'pub_year': '2015',
#     'citation': 'Computational and Mathematical Models in Vision, 2015'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:g3aElNc5_aQC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3803486257224325801',
#    'cites_id': ['3803486257224325801']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Limits on the estimation of shape from specular surfaces',
#     'pub_year': '2014',
#     'citation': 'Journal of Vision 14 (10), 721-721, 2014'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:L7CI7m0gUJcC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17673231121540755451',
#    'cites_id': ['17673231121540755451']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'The tipping point: Visual estimation of the physical stability of three-dimensional objects',
#     'pub_year': '2013',
#     'citation': 'RUTGERS THE STATE UNIVERSITY OF NEW JERSEY-NEW, 2013'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:WF5omc3nYNoC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10966284922852760188',
#    'cites_id': ['10966284922852760188'],
#    'public_access': True},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Perception of Physical Stability of Asymmetrical Three-Dimensional Objects',
#     'pub_year': '2011',
#     'citation': 'Journal of Vision 11 (11), 44-44, 2011'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:YsMSGLbcyi4C',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16519466829062962063',
#    'cites_id': ['16519466829062962063'],
#    'public_access': True},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Cutaneous perception',
#     'pub_year': '2010',
#     'citation': 'Encyclopedia of Perception 1, 343–348, 2010'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:AvfA0Oy_GE0C',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1034832298898815382',
#    'cites_id': ['1034832298898815382']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Creating correct aberrations: why blur isn’t always bad in the eye',
#     'pub_year': '2020',
#     'citation': 'Adaptive Optics and Wavefront Control for Biological Systems VI 11248, 57-63, 2020'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:SpbeaW3--B0C',
#    'num_citations': 0,
#    'public_access': True},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Real-time blur with chromatic aberration drives accommodation and depth perception',
#     'pub_year': '2019',
#     'citation': 'Journal of Vision 19 (10), 15b-15b, 2019'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:S16KYo8Pm5AC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Peripheral stimulation can override foveal stimulation in driving accommodation',
#     'pub_year': '2019',
#     'citation': 'Investigative Ophthalmology & Visual Science 60 (9), 1402-1402, 2019'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:e_rmSamDkqQC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'ChromaBlur: Rendering natural chromatic aberration drives accommodation effectively',
#     'pub_year': '2018',
#     'citation': 'Journal of Vision 18 (10), 582-582, 2018'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:oNZyr7d5Mn4C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Driving accommodation using simulated higher-order aberrations',
#     'pub_year': '2018',
#     'citation': 'Journal of Vision 18 (10), 500-500, 2018'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:M7yex6snE4oC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Modeling Accommodation Control of the Human Eye: Chromatic Aberration and Color Opponency',
#     'pub_year': '2017',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:b1wdh0AR-JQC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'The Dark Secrets of Dirty Concavities',
#     'pub_year': '2014',
#     'citation': 'Journal of Vision 14 (10), 1317-1317, 2014'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:ILKRHgRFtOwC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'What happens to a shiny 3D object in a rotating environment?',
#     'pub_year': '2014',
#     'citation': 'Visual Sciences Society (VSS) Annual Meeting Demo Night, 2014'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:vbGhcppDl1QC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Effects of varied spatial scale on perception of shape from shiny surfaces',
#     'pub_year': '2014',
#     'citation': 'Tagung experimentell arbeitender Psychologen (TeaP, Conference of …, 2014'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:4MWp96NkSFoC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Visually disentangling shading and surface pigmentation when the two are correlated',
#     'pub_year': '2014',
#     'citation': 'Tagung experimentell arbeitender Psychologen (TeaP, Conference of …, 2014'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:ML0RJ9NH7IQC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Perceptual regions of interest for 3D shape derived from shading and texture flows',
#     'pub_year': '2014',
#     'citation': 'Tagung experimentell arbeitender Psychologen (TeaP, Conference of …, 2014'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:Z5m8FVwuT1cC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Visual perception of the physical stability of asymmetric three',
#     'pub_year': '2013',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:kuK5TVdYjLIC',
#    'num_citations': 0,
#    'public_access': True},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Visual adaptation to physical stability of objects',
#     'pub_year': '2012',
#     'citation': 'Journal of Vision 12 (9), 304-304, 2012'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:W7OEmFMy1HYC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Curvature aftereffect and visual-haptic interactions in simulated environments',
#     'pub_year': '2011',
#     'citation': 'Journal of Vision 11 (11), 784-784, 2011'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:2osOgNQ5qMEC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'On the edge: Perceived stability and center of mass of 3D objects',
#     'pub_year': '2011',
#     'citation': 'Perception 40, 101, 2011'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:Y0pCki6q_DkC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Perceiving intelligent action: Experiments in the interpretation of intentional motion',
#     'pub_year': '2011',
#     'citation': 'IGERT 2011 poster competition, 2011'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:IjCSPb-OGe4C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': '2010 Index IEEE Transactions on Haptics Vol. 3',
#     'pub_year': '2010',
#     'citation': 'IEEE Transactions on Haptics 3 (4), 1, 2010'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:WZBGuue-350C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Living within a virtual environment populated by intelligent autonomous agents',
#     'pub_year': '2010',
#     'citation': 'NSF IGERT 2010 Project Meeting, 2010'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:UeHWp8X0CEIC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Pain: Physiological mechanisms',
#     'pub_year': '2010',
#     'citation': 'Encyclopedia of Perception 1, 722–726, 2010'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:BUYA1_V_uYcC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Perceptual estimation of variance in orientation and its dependence on sample size',
#     'pub_year': '2009',
#     'citation': 'Journal of Vision 9 (8), 1019, 2009'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:BwyfMAYsbu0C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Haptic stiffness identification and information transfer',
#     'pub_year': '2007',
#     'citation': 'Psychonomic Society, 48th Annual Meeting, 83, 2007'},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:p__nRnzSRKYC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'This manuscript has been accepted for publication at Decision',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': '4bahYMkAAAAJ:tYavs44e6CUC',
#    'num_citations': 0}],
#  'public_access': {'available': 12, 'not_available': 0}}

# %%
scholarly.pprint(author)
# Out:
# b'{\'affiliation\': \'Vision Scientist at Google LLC\',\n \'citedby\': 444,\n \'citedby5y\': 308,\n \'cites_per_year\': {2008: 3,\n                    2009: 5,\n                    2010: 7,\n                    2011: 9,\n                    2012: 22,\n                    2013: 17,\n                    2014: 16,\n                    2015: 17,\n                    2016: 36,\n                    2017: 32,\n                    2018: 30,\n                    2019: 57,\n                    2020: 66,\n                    2021: 78,\n                    2022: 44},\n \'coauthors\': [{\'affiliation\': \'Professor of Vision Science, UC Berkeley\',\n                \'filled\': False,\n                \'name\': \'Martin Banks\',\n                \'scholar_id\': \'Smr99uEAAAAJ\',\n                \'source\': \'CO_AUTHORS_LIST\'},\n               {\'affiliation\': \'Kurt Koffka Professor of Experimental \'\n                               \'Psychology, University of Giessen\',\n                \'filled\': False,\n                \'name\': \'Roland Fleming\',\n                \'scholar_id\': \'ruUKktgAAAAJ\',\n                \'source\': \'CO_AUTHORS_LIST\'},\n               {\'affiliation\': \'Durham University, Computer Science & Physics\',\n                \'filled\': False,\n                \'name\': \'Gordon D. Love\',\n                \'scholar_id\': \'3xJXtlwAAAAJ\',\n                \'source\': \'CO_AUTHORS_LIST\'},\n               {\'affiliation\': \'Professor of ECE, Purdue University\',\n                \'filled\': False,\n                \'name\': \'Hong Z Tan\',\n                \'scholar_id\': \'OiVOAHMAAAAJ\',\n                \'source\': \'CO_AUTHORS_LIST\'},\n               {\'affiliation\': \'Deepmind\',\n                \'filled\': False,\n                \'name\': \'Ari Weinstein\',\n                \'scholar_id\': \'MnUboHYAAAAJ\',\n                \'source\': \'CO_AUTHORS_LIST\'},\n               {\'affiliation\': "Brigham and Women\'s Hospital/Harvard Medical "\n                               \'School\',\n                \'filled\': False,\n                \'name\': \'Chia-Chien Wu\',\n                \'scholar_id\': \'dqokykoAAAAJ\',\n                \'source\': \'CO_AUTHORS_LIST\'},\n               {\'affiliation\': \'Professor of Psychology and Cognitive Science, \'\n                               \'Rutgers University\',\n                \'filled\': False,\n                \'name\': \'Jacob Feldman\',\n                \'scholar_id\': \'KoJrMIAAAAAJ\',\n                \'source\': \'CO_AUTHORS_LIST\'},\n               {\'affiliation\': \'Research Scientist at Google Research\',\n                \'filled\': False,\n                \'name\': \'Pratul Srinivasan\',\n                \'scholar_id\': \'aYyDsZ0AAAAJ\',\n                \'source\': \'CO_AUTHORS_LIST\'},\n               {\'affiliation\': \'Rutgers University, New Brunswick, NJ\',\n                \'filled\': False,\n                \'name\': \'Manish Singh\',\n                \'scholar_id\': \'9XRvM88AAAAJ\',\n                \'source\': \'CO_AUTHORS_LIST\'},\n               {\'affiliation\': \'Senior Director - Clinical Affairs, Neurolens \'\n                               \'Inc.,\',\n                \'filled\': False,\n                \'name\': \'Vivek Labhishetty\',\n                \'scholar_id\': \'tD7OGTQAAAAJ\',\n                \'source\': \'CO_AUTHORS_LIST\'},\n               {\'affiliation\': \'Professor in Computer Science, University of \'\n                               \'California, Berkeley\',\n                \'filled\': False,\n                \'name\': \'Ren Ng\',\n                \'scholar_id\': \'6H0mhLUAAAAJ\',\n                \'source\': \'CO_AUTHORS_LIST\'},\n               {\'affiliation\': \'Formerly: Indiana University, Rutgers \'\n                               \'University, University of Pennsylvania\',\n                \'filled\': False,\n                \'name\': \'Peter C. Pantelis\',\n                \'scholar_id\': \'FoVvIK0AAAA ...

# %%
first_publication = author['publications'][0]
first_publication
# Out:
# {'container_type': 'Publication',
#  'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#  'bib': {'title': 'A frequency-domain analysis of haptic gratings',
#   'pub_year': '2009',
#   'citation': 'IEEE Transactions on Haptics 3 (1), 3-14, 2009'},
#  'filled': False,
#  'author_pub_id': '4bahYMkAAAAJ:u5HHmVD_uO8C',
#  'num_citations': 63,
#  'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=18104797610932568627',
#  'cites_id': ['18104797610932568627']}

# %%
first_publication_filled = scholarly.fill(first_publication)
first_publication_filled
# Out:
# {'container_type': 'Publication',
#  'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#  'bib': {'title': 'A frequency-domain analysis of haptic gratings',
#   'pub_year': 2009,
#   'citation': 'IEEE Transactions on Haptics 3 (1), 3-14, 2009',
#   'author': 'Steven A Cholewiak and Kwangtaek Kim and Hong Z Tan and Bernard D Adelstein',
#   'journal': 'IEEE Transactions on Haptics',
#   'volume': '3',
#   'number': '1',
#   'pages': '3-14',
#   'publisher': 'IEEE',
#   'abstract': 'The detectability and discriminability of virtual haptic gratings were analyzed in the frequency domain. Detection (Exp. 1) and discrimination (Exp. 2) thresholds for virtual haptic gratings were estimated using a force-feedback device that simulated sinusoidal and square-wave gratings with spatial periods from 0.2 to 38.4 mm. The detection threshold results indicated that for spatial periods up to 6.4 mm (i.e., spatial frequencies >0.156 cycle/mm), the detectability of square-wave gratings could be predicted quantitatively from the detection thresholds of their corresponding fundamental components. The discrimination experiment confirmed that at higher spatial frequencies, the square-wave gratings were initially indistinguishable from the corresponding fundamental components until the third harmonics were detectable. At lower spatial frequencies, the third harmonic components of square-wave gratings had lower …'},
#  'filled': True,
#  'author_pub_id': '4bahYMkAAAAJ:u5HHmVD_uO8C',
#  'num_citations': 63,
#  'citedby_url': '/scholar?hl=en&cites=18104797610932568627',
#  'cites_id': ['18104797610932568627'],
#  'pub_url': 'https://ieeexplore.ieee.org/abstract/document/5210096/',
#  'url_related_articles': '/scholar?oi=bibs&hl=en&q=related:MwL6-YApQfsJ:scholar.google.com/',
#  'cites_per_year': {2010: 2,
#   2011: 7,
#   2012: 10,
#   2013: 5,
#   2014: 3,
#   2015: 4,
#   2016: 4,
#   2017: 5,
#   2018: 3,
#   2019: 3,
#   2020: 9,
#   2021: 6,
#   2022: 2}}

# %%
publication_titles = [pub['bib']['title'] for pub in author['publications']]

# %%
print(publication_titles)
# Out:
# ['A frequency-domain analysis of haptic gratings', 'Haptic identification of stiffness and force magnitude', 'Chromablur: Rendering chromatic eye aberration improves accommodation and realism', 'Creating correct blur and its effect on accommodation', 'Inferring the intentional states of autonomous virtual agents', 'Visual perception of the physical stability of asymmetric three-dimensional objects', 'Perception of physical stability and center of mass of 3-D objects', 'Colour, contours, shading and shape: flow interactions reveal anchor neighbourhoods', "Contributions of foveal and non-foveal retina to the human eye's focusing response", 'Discrimination of real and virtual surfaces with sinusoidal and triangular gratings using the fingertip and stylus', 'A perceptual eyebox for near-eye displays', 'Varifocal virtuality: a novel optical layout for near-eye display', 'Agency and rationality: Adopting the intentional stance toward evolved virtual agents.', 'Lags and leads of accommodation in humans: Fact or fiction?', 'Intra-and intermanual curvature aftereffect can be obtained via tool-touch', 'Perception of intentions and mental states in autonomous virtual agents', 'Frequency analysis of the detectability of virtual haptic gratings', 'Distinguishing between texture and shading flows for 3D shape estimation', 'Predicting 3D shape perception from shading and texture flows', 'The perception of physical stability of 3d objects: The role of parts', 'Optimal allocation of quantized human eye depth perception for multi-focal 3D display design', 'Towards a unified explanation of shape from shading and texture', 'Lags and leads of accommodation are smaller than previously thought', 'Pseudo light-field display apparatus', 'ChromaBlur: Rendering Chromatic Eye Aberration Improves Accommodation and Realism in HMDs', 'Lags and leads of accommodation: Fact or fiction?', 'Rendering correct blur', 'Appearance controls interpretation of orientation flows for 3D shape estimation', 'Limits on the estimation of shape from specular surfaces', 'The tipping point: Visual estimation of the physical stability of three-dimensional objects', 'Perception of Physical Stability of Asymmetrical Three-Dimensional Objects', 'Cutaneous perception', 'Creating correct aberrations: why blur isn’t always bad in the eye', 'Real-time blur with chromatic aberration drives accommodation and depth perception', 'Peripheral stimulation can override foveal stimulation in driving accommodation', 'ChromaBlur: Rendering natural chromatic aberration drives accommodation effectively', 'Driving accommodation using simulated higher-order aberrations', 'Modeling Accommodation Control of the Human Eye: Chromatic Aberration and Color Opponency', 'The Dark Secrets of Dirty Concavities', 'What happens to a shiny 3D object in a rotating environment?', 'Effects of varied spatial scale on perception of shape from shiny surfaces', 'Visually disentangling shading and surface pigmentation when the two are correlated', 'Perceptual regions of interest for 3D shape derived from shading and texture flows', 'Visual perception of the physical stability of asymmetric three', 'Visual adaptation to physical stability of objects', 'Curvature aftereffect and visual-haptic interactions in simulated environments', 'On the edge: Perceived stability and center of mass of 3D objects', 'Perceiving intelligent action: Experiments in the interpretation of intentional motion', '2010 Index IEEE Transactions on Haptics Vol. 3', 'Living within a virtual environment populated by intelligent autonomous agents', 'Pain: Physiological mechanisms', 'Perceptual estimation of variance in orientation and its dependence on sample size', 'Haptic stiffness identification and information transfer', 'This manuscript has been accepted for publication at Decision']

# %%
citations = [citation['bib']['title'] for citation in scholarly.citedby(first_publication_filled)]
print(citations)
# Out:
# ['Application of psychophysical techniques to haptic research', 'Tactile and haptic illusions', 'Modeling and rendering realistic textures from unconstrained tool-surface interactions', 'Effect of waveform on tactile perception by electrovibration displayed on touch screens', 'One hundred data-driven haptic texture models and open-source methods for rendering on 3D objects', 'Performance metrics for haptic interfaces', 'Generating haptic texture models from unconstrained tool-surface interactions', 'Emotional responses of tactile icons: Effects of amplitude, frequency, duration, and envelope', 'Roughness perception of virtual textures displayed by electrovibration on touch screens', 'Lossy data compression of vibrotactile material-like textures', 'Data-driven modeling of isotropic haptic textures using frequency-decomposed neural networks', 'Dynamic simulation of tool-mediated texture interaction', 'Perceptual properties of vibrotactile material texture: Effects of amplitude changes and stimuli beneath detection thresholds', "What you can't feel won't hurt you: Evaluating haptic hardware using a haptic contrast sensitivity function", 'Haptics as an interaction modality', 'Just noticeable differences of low-intensity vibrotactile forces at the fingertip', 'Discrimination of real and virtual surfaces with sinusoidal and triangular gratings using the fingertip and stylus', 'Single pitch perception of multi-frequency textures', 'A physics-based vibrotactile feedback library for collision events', 'Detection and discrimination thresholds for haptic gratings on electrostatic tactile displays', 'Relationship between tactual roughness judgment and surface morphology of fabric by fingertip touching method', 'Virtual active touch: Perception of virtual gratings wavelength through pointing-stick interface', 'Roughness rendering by sinusoidal friction modulation: Perceived intensity and gradient discrimination*', 'High-bandwidth tribometry as a means of recording natural textures', 'Spectrum-based synthesis of vibrotactile stimuli: Active footstep display for crinkle of fragile structures', 'Phase difference between normal and shear forces during tactile exploration represents textural features', 'Stochastic relationships between the normal and shear interaction forces during tactile exploration of textures', 'The physical basis of perceived roughness in virtual sinusoidal textures', 'Analysis of fingertip/fabric friction-induced vibration signals toward vibrotactile rendering', 'Improving the prediction of haptic impression user ratings using perception-based weighting methods: experimental evaluation', 'Spectrum-based vibrotactile footstep-display for crinkle of fragile structures', 'Development of a multiple contact haptic display with texture-enhanced graphics', 'Learning an action-conditional model for haptic texture generation', 'Towards multisensory perception: Modeling and rendering sounds of tool-surface interactions', 'Building a navigable fine texture design space', 'Wearable finger pad deformation sensor for tactile textures in frequency domain by using accelerometer on finger side', 'Estimation of torso vibrotactile thresholds using eccentric rotating mass motors', 'Tactile perception of natural and simulated textures: A psychophysical approach', '基于频谱分析的织物粗糙感', 'Visual-tactile cross-modal data generation using residue-fusion GAN with feature-matching and perceptual losses', 'Tactile perception by electrovibration', 'Data-driven haptic modeling and rendering of realistic virtual textured surfaces', 'Distinguishability of periodic haptic stimuli in the frequency domain', 'Psychophysical validation of interleaving narrowband tactile stimuli to achieve broadband effects', 'Web-Based Virtual Workplace Environment for Improving Safety', 'Vibrotactile display of patterned surface textures with kinesthetic haptic devices using balanced impulses', 'The human perception of haptic vibrations', 'Design, characterisation and application  ...

# %%
type(first_author_result)
# Out:
# dict

# %%
search_query = scholarly.search_keyword('Adem Kalınlı')
(next(search_query))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 search_query = scholarly.search_keyword('Adem Kalınlı')
# ----> 2 (next(search_query))
#
# StopIteration:
